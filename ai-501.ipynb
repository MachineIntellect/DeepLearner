# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
坐标list = [[1,0],[1,1],[0,0]]
坐标arr = array(坐标list)

# %%
x = 坐标arr[:,0]
x
# Out:
# array([1, 1, 0])

# %%
y = 坐标arr[:,1]
y
# Out:
# array([0, 1, 0])
