# %% [markdown]
# # 铺垫

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# # 示例6-7

# %%
a = np.array([[]])
a
# Out:
# array([], shape=(1, 0), dtype=float64)

# %%
a.ndim
# Out:
# 2
